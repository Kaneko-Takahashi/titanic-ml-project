# %%
# 簡単な動作テスト：サンプルデータ作成
test_data = pd.DataFrame({
    'feature1': [1, 2, 3, 4, 5],
    'feature2': [10, 20, 30, 40, 50],
    'target': [0, 0, 1, 1, 1]
})

print("📊 テストデータ:")
print(test_data)
print(f"\nデータ型: {type(test_data)}")
print(f"形状: {test_data.shape}")
print("\n✅ pandas DataFrame の作成・表示が正常に動作しています！")
# Out:
# 📊 テストデータ:
#    feature1  feature2  target
# 0         1        10       0
# 1         2        20       0
# 2         3        30       1
# 3         4        40       1
# 4         5        50       1
#
# データ型: <class 'pandas.core.frame.DataFrame'>
# 形状: (5, 3)
#
# ✅ pandas DataFrame の作成・表示が正常に動作しています！

# %%
# バージョン確認
import sklearn

print("=" * 50)
print("🔍 インストール済みライブラリのバージョン")
print("=" * 50)
print(f"pandas:       {pd.__version__}")
print(f"numpy:        {np.__version__}")
print(f"seaborn:      {sns.__version__}")
print(f"scikit-learn: {sklearn.__version__}")
print(f"matplotlib:   {plt.matplotlib.__version__}")
print("=" * 50)
# Out:
# ==================================================
# 🔍 インストール済みライブラリのバージョン
# ==================================================
# pandas:       2.2.3
# numpy:        1.26.4
# seaborn:      0.13.2
# scikit-learn: 1.5.2
# matplotlib:   3.9.2
# ==================================================

# %%
# ライブラリのインポート確認
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

print("✅ すべてのライブラリが正常にインポートされました！")
# Out:
# ✅ すべてのライブラリが正常にインポートされました！
